# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo
# %load_ext nengo.ipynb
from nengo.dists import Uniform
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot, set_color_cycle
set_color_cycle(["#377EB8", "#E41A1C", "#4DAF4A", "#984EA3", "#FF7F00", "#222222", "#A65628", "#E7298A"])

def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1],[-1]], (n_neurons/2,1))
    intercepts *= encoders[:,0]
    return intercepts, encoders

hide_input()
# Out:
#         <a id="1197032276" href="javascript:toggle_input_1197032276()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1197032276;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1197032276 = document.getElementById("1197032276");
#                 var cell = link_1197032276;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1197032276;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1197032276 = cell.children[i];
#                 }
#                 input_1197032276.style.display = "none"; // hide
#
#                 toggle_input_1197032276 = function() {
#                     if (input_1197032276.style.display == "none") {
#                         input_1197032276.style.display = ""; // show
#                         link_1197032276.innerHTML = "Hide Input";
#                     } else {
#                         input_1197032276.style.display = "none"; // hide
#                         link_1197032276.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1197032276 = $("a[id='1197032276']");
#                 var cell_1197032276 = link_1197032276.parents("div.cell:first");
#                 var input_1197032276 = cell_1197032276.children("div.input");
#                 input_1197032276.hide();
#
#                 toggle_input_1197032276 = function() {
#                     if (input_1197032276.is(':hidden')) {
#                         input_1197032276.slideDown();
#                         link_1197032276[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1197032276.slideUp();
#                         link_1197032276[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Introduction
# The Neural Engineering Framework (NEF) is the set of theoretical methods that are used in Nengo for constructing neural models.  The NEF is based on <a href="http://www.amazon.com/gp/product/0262550601">Eliasmith & Anderson's (2003) book</a> from MIT Press. This notebook introduces the three main principles discussed in that book and implemented in Nengo.

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals through their spiking responses. A signal is a vector of real numbers of arbitrary length. This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1046431940" href="javascript:toggle_input_1046431940()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1046431940;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1046431940 = document.getElementById("1046431940");
#                 var cell = link_1046431940;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1046431940;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1046431940 = cell.children[i];
#                 }
#                 input_1046431940.style.display = "none"; // hide
#
#                 toggle_input_1046431940 = function() {
#                     if (input_1046431940.style.display == "none") {
#                         input_1046431940.style.display = ""; // show
#                         link_1046431940.innerHTML = "Hide Input";
#                     } else {
#                         input_1046431940.style.display = "none"; // hide
#                         link_1046431940.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1046431940 = $("a[id='1046431940']");
#                 var cell_1046431940 = link_1046431940.parents("div.cell:first");
#                 var input_1046431940 = cell_1046431940.children("div.input");
#                 input_1046431940.hide();
#
#                 toggle_input_1046431940 = function() {
#                     if (input_1046431940.is(':hidden')) {
#                         input_1046431940.slideDown();
#                         link_1046431940[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1046431940.slideUp();
#                         link_1046431940[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F (current-frequency) curve, if you're familiar with that).
#
# The tuning curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)

# %%
with nengo.Simulator(model) as sim:

    eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="278680946" href="javascript:toggle_input_278680946()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_278680946;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_278680946 = document.getElementById("278680946");
#                 var cell = link_278680946;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_278680946;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_278680946 = cell.children[i];
#                 }
#                 input_278680946.style.display = "none"; // hide
#
#                 toggle_input_278680946 = function() {
#                     if (input_278680946.style.display == "none") {
#                         input_278680946.style.display = ""; // show
#                         link_278680946.innerHTML = "Hide Input";
#                     } else {
#                         input_278680946.style.display = "none"; // hide
#                         link_278680946.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_278680946 = $("a[id='278680946']");
#                 var cell_278680946 = link_278680946.parents("div.cell:first");
#                 var input_278680946 = cell_278680946.children("div.input");
#                 input_278680946.hide();
#
#                 toggle_input_278680946 = function() {
#                     if (input_278680946.is(':hidden')) {
#                         input_278680946.slideDown();
#                         link_278680946[0].innerHTML = "Hide Input";
#                     } else {
#                         input_278680946.slideUp();
#                         link_278680946[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1174609916" href="javascript:toggle_input_1174609916()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1174609916;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1174609916 = document.getElementById("1174609916");
#                 var cell = link_1174609916;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1174609916;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1174609916 = cell.children[i];
#                 }
#                 input_1174609916.style.display = "none"; // hide
#
#                 toggle_input_1174609916 = function() {
#                     if (input_1174609916.style.display == "none") {
#                         input_1174609916.style.display = ""; // show
#                         link_1174609916.innerHTML = "Hide Input";
#                     } else {
#                         input_1174609916.style.display = "none"; // hide
#                         link_1174609916.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1174609916 = $("a[id='1174609916']");
#                 var cell_1174609916 = link_1174609916.parents("div.cell:first");
#                 var input_1174609916 = cell_1174609916.children("div.input");
#                 input_1174609916.hide();
#
#                 toggle_input_1174609916 = function() {
#                     if (input_1174609916.is(':hidden')) {
#                         input_1174609916.slideDown();
#                         link_1174609916[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1174609916.slideUp();
#                         link_1174609916[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded by decoding the pattern of spikes. To do this, we first filter the spike train with a temporal filter that accounts for postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 0.18
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:,i] - i*scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons+1), scale)
plt.ylabel("Neuron")
plt.yticks(np.arange(scale/1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons));
hide_input()
# Out:
#         <a id="743107353" href="javascript:toggle_input_743107353()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_743107353;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_743107353 = document.getElementById("743107353");
#                 var cell = link_743107353;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_743107353;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_743107353 = cell.children[i];
#                 }
#                 input_743107353.style.display = "none"; // hide
#
#                 toggle_input_743107353 = function() {
#                     if (input_743107353.style.display == "none") {
#                         input_743107353.style.display = ""; // show
#                         link_743107353.innerHTML = "Hide Input";
#                     } else {
#                         input_743107353.style.display = "none"; // hide
#                         link_743107353.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_743107353 = $("a[id='743107353']");
#                 var cell_743107353 = link_743107353.parents("div.cell:first");
#                 var input_743107353 = cell_743107353.children("div.input");
#                 input_743107353.hide();
#
#                 toggle_input_743107353 = function() {
#                     if (input_743107353.is(':hidden')) {
#                         input_743107353.slideDown();
#                         link_743107353[0].innerHTML = "Hide Input";
#                     } else {
#                         input_743107353.slideUp();
#                         link_743107353[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together to give an estimate of the input based on the spikes.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="18755645" href="javascript:toggle_input_18755645()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_18755645;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_18755645 = document.getElementById("18755645");
#                 var cell = link_18755645;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_18755645;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_18755645 = cell.children[i];
#                 }
#                 input_18755645.style.display = "none"; // hide
#
#                 toggle_input_18755645 = function() {
#                     if (input_18755645.style.display == "none") {
#                         input_18755645.style.display = ""; // show
#                         link_18755645.innerHTML = "Hide Input";
#                     } else {
#                         input_18755645.style.display = "none"; // hide
#                         link_18755645.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_18755645 = $("a[id='18755645']");
#                 var cell_18755645 = link_18755645.parents("div.cell:first");
#                 var input_18755645 = cell_18755645.children("div.input");
#                 input_18755645.hide();
#
#                 toggle_input_18755645 = function() {
#                     if (input_18755645.is(':hidden')) {
#                         input_18755645.slideDown();
#                         link_18755645[0].innerHTML = "Hide Input";
#                     } else {
#                         input_18755645.slideUp();
#                         link_18755645[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1077520236" href="javascript:toggle_input_1077520236()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1077520236;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1077520236 = document.getElementById("1077520236");
#                 var cell = link_1077520236;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1077520236;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1077520236 = cell.children[i];
#                 }
#                 input_1077520236.style.display = "none"; // hide
#
#                 toggle_input_1077520236 = function() {
#                     if (input_1077520236.style.display == "none") {
#                         input_1077520236.style.display = ""; // show
#                         link_1077520236.innerHTML = "Hide Input";
#                     } else {
#                         input_1077520236.style.display = "none"; // hide
#                         link_1077520236.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1077520236 = $("a[id='1077520236']");
#                 var cell_1077520236 = link_1077520236.parents("div.cell:first");
#                 var input_1077520236 = cell_1077520236.children("div.input");
#                 input_1077520236.hide();
#
#                 toggle_input_1077520236 = function() {
#                     if (input_1077520236.is(':hidden')) {
#                         input_1077520236.slideDown();
#                         link_1077520236[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1077520236.slideUp();
#                         link_1077520236[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.processes import WhiteSignal

model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1795048796" href="javascript:toggle_input_1795048796()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1795048796;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1795048796 = document.getElementById("1795048796");
#                 var cell = link_1795048796;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1795048796;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1795048796 = cell.children[i];
#                 }
#                 input_1795048796.style.display = "none"; // hide
#
#                 toggle_input_1795048796 = function() {
#                     if (input_1795048796.style.display == "none") {
#                         input_1795048796.style.display = ""; // show
#                         link_1795048796.innerHTML = "Hide Input";
#                     } else {
#                         input_1795048796.style.display = "none"; // hide
#                         link_1795048796.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1795048796 = $("a[id='1795048796']");
#                 var cell_1795048796 = link_1795048796.parents("div.cell:first");
#                 var input_1795048796 = cell_1795048796.children("div.input");
#                 input_1795048796.hide();
#
#                 toggle_input_1795048796 = function() {
#                     if (input_1795048796.is(':hidden')) {
#                         input_1795048796.slideDown();
#                         link_1795048796[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1795048796.slideUp();
#                         link_1795048796[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input,)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="2039825134" href="javascript:toggle_input_2039825134()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2039825134;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2039825134 = document.getElementById("2039825134");
#                 var cell = link_2039825134;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2039825134;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2039825134 = cell.children[i];
#                 }
#                 input_2039825134.style.display = "none"; // hide
#
#                 toggle_input_2039825134 = function() {
#                     if (input_2039825134.style.display == "none") {
#                         input_2039825134.style.display = ""; // show
#                         link_2039825134.innerHTML = "Hide Input";
#                     } else {
#                         input_2039825134.style.display = "none"; // hide
#                         link_2039825134.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2039825134 = $("a[id='2039825134']");
#                 var cell_2039825134 = link_2039825134.parents("div.cell:first");
#                 var input_2039825134 = cell_2039825134.children("div.input");
#                 input_2039825134.hide();
#
#                 toggle_input_2039825134 = function() {
#                     if (input_2039825134.is(':hidden')) {
#                         input_2039825134.slideDown();
#                         link_2039825134[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2039825134.slideUp();
#                         link_2039825134[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes. We told Nengo to compute a new set of decoders that estimate the function $x^2$.
#
# In general, the transformation principle determines how we can decode spike trains to compute linear and nonlinear transformations of signals encoded in a population of neurons. We can then project those transformed signals into another population, and repeat the process.  Essentially, this provides a means of computing the neural connection weights to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="509760272" href="javascript:toggle_input_509760272()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_509760272;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_509760272 = document.getElementById("509760272");
#                 var cell = link_509760272;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_509760272;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_509760272 = cell.children[i];
#                 }
#                 input_509760272.style.display = "none"; // hide
#
#                 toggle_input_509760272 = function() {
#                     if (input_509760272.style.display == "none") {
#                         input_509760272.style.display = ""; // show
#                         link_509760272.innerHTML = "Hide Input";
#                     } else {
#                         input_509760272.style.display = "none"; // hide
#                         link_509760272.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_509760272 = $("a[id='509760272']");
#                 var cell_509760272 = link_509760272.parents("div.cell:first");
#                 var input_509760272 = cell_509760272.children("div.input");
#                 input_509760272.hide();
#
#                 toggle_input_509760272 = function() {
#                     if (input_509760272.is(':hidden')) {
#                         input_509760272.slideDown();
#                         link_509760272[0].innerHTML = "Hide Input";
#                     } else {
#                         input_509760272.slideUp();
#                         link_509760272[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights. Let us flip this sine wave upside down as it is transmitted between two populations (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2,2,3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2,2,2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2,2,4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1753657986" href="javascript:toggle_input_1753657986()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1753657986;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1753657986 = document.getElementById("1753657986");
#                 var cell = link_1753657986;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1753657986;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1753657986 = cell.children[i];
#                 }
#                 input_1753657986.style.display = "none"; // hide
#
#                 toggle_input_1753657986 = function() {
#                     if (input_1753657986.style.display == "none") {
#                         input_1753657986.style.display = ""; // show
#                         link_1753657986.innerHTML = "Hide Input";
#                     } else {
#                         input_1753657986.style.display = "none"; // hide
#                         link_1753657986.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1753657986 = $("a[id='1753657986']");
#                 var cell_1753657986 = link_1753657986.parents("div.cell:first");
#                 var input_1753657986 = cell_1753657986.children("div.input");
#                 input_1753657986.hide();
#
#                 toggle_input_1753657986 = function() {
#                     if (input_1753657986.is(':hidden')) {
#                         input_1753657986.slideDown();
#                         link_1753657986[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1753657986.slideUp();
#                         link_1753657986[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights. Let us add a third population connected to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="280904753" href="javascript:toggle_input_280904753()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_280904753;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_280904753 = document.getElementById("280904753");
#                 var cell = link_280904753;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_280904753;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_280904753 = cell.children[i];
#                 }
#                 input_280904753.style.display = "none"; // hide
#
#                 toggle_input_280904753 = function() {
#                     if (input_280904753.style.display == "none") {
#                         input_280904753.style.display = ""; // show
#                         link_280904753.innerHTML = "Hide Input";
#                     } else {
#                         input_280904753.style.display = "none"; // hide
#                         link_280904753.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_280904753 = $("a[id='280904753']");
#                 var cell_280904753 = link_280904753.parents("div.cell:first");
#                 var input_280904753 = cell_280904753.children("div.input");
#                 input_280904753.hide();
#
#                 toggle_input_280904753 = function() {
#                     if (input_280904753.is(':hidden')) {
#                         input_280904753.slideDown();
#                         link_280904753[0].innerHTML = "Hide Input";
#                     } else {
#                         input_280904753.slideUp();
#                         link_280904753[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we have been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory or dynamic systems theory to brain models.  Nengo automatically translates from standard dynamical systems descriptions to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics, we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator implemented using this third principle. It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1,0] if t < 0.1 else [0,0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator,
                     transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1,2,2)
plt.plot(sim.data[oscillator_probe][:,0], sim.data[oscillator_probe][:,1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$');
hide_input()
# Out:
#         <a id="1474943389" href="javascript:toggle_input_1474943389()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1474943389;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1474943389 = document.getElementById("1474943389");
#                 var cell = link_1474943389;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1474943389;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1474943389 = cell.children[i];
#                 }
#                 input_1474943389.style.display = "none"; // hide
#
#                 toggle_input_1474943389 = function() {
#                     if (input_1474943389.style.display == "none") {
#                         input_1474943389.style.display = ""; // show
#                         link_1474943389.innerHTML = "Hide Input";
#                     } else {
#                         input_1474943389.style.display = "none"; // hide
#                         link_1474943389.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1474943389 = $("a[id='1474943389']");
#                 var cell_1474943389 = link_1474943389.parents("div.cell:first");
#                 var input_1474943389 = cell_1474943389.children("div.input");
#                 input_1474943389.hide();
#
#                 toggle_input_1474943389 = function() {
#                     if (input_1474943389.is(':hidden')) {
#                         input_1474943389.slideDown();
#                         link_1474943389[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1474943389.slideUp();
#                         link_1474943389[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
