# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo
# %load_ext nengo.ipynb
from nengo.dists import Uniform
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot, set_color_cycle
set_color_cycle(["#377EB8", "#E41A1C", "#4DAF4A", "#984EA3", "#FF7F00", "#222222", "#A65628", "#E7298A"])

def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1],[-1]], (n_neurons/2,1))
    intercepts *= encoders[:,0]
    return intercepts, encoders

hide_input()
# Out:
#         <a id="593994853" href="javascript:toggle_input_593994853()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_593994853;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_593994853 = document.getElementById("593994853");
#                 var cell = link_593994853;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_593994853;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_593994853 = cell.children[i];
#                 }
#                 input_593994853.style.display = "none"; // hide
#
#                 toggle_input_593994853 = function() {
#                     if (input_593994853.style.display == "none") {
#                         input_593994853.style.display = ""; // show
#                         link_593994853.innerHTML = "Hide Input";
#                     } else {
#                         input_593994853.style.display = "none"; // hide
#                         link_593994853.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_593994853 = $("a[id='593994853']");
#                 var cell_593994853 = link_593994853.parents("div.cell:first");
#                 var input_593994853 = cell_593994853.children("div.input");
#                 input_593994853.hide();
#
#                 toggle_input_593994853 = function() {
#                     if (input_593994853.is(':hidden')) {
#                         input_593994853.slideDown();
#                         link_593994853[0].innerHTML = "Hide Input";
#                     } else {
#                         input_593994853.slideUp();
#                         link_593994853[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Introduction
# The Neural Engineering Framework (NEF) is the set of theoretical methods that are used in Nengo for constructing neural models.  The NEF is based on <a href="http://www.amazon.com/gp/product/0262550601">Eliasmith & Anderson's (2003) book</a> from MIT Press. This notebook introduces the three main principles discussed in that book and implemented in Nengo.

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals through their spiking responses. A signal is a vector of real numbers of arbitrary length. This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1488052069" href="javascript:toggle_input_1488052069()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1488052069;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1488052069 = document.getElementById("1488052069");
#                 var cell = link_1488052069;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1488052069;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1488052069 = cell.children[i];
#                 }
#                 input_1488052069.style.display = "none"; // hide
#
#                 toggle_input_1488052069 = function() {
#                     if (input_1488052069.style.display == "none") {
#                         input_1488052069.style.display = ""; // show
#                         link_1488052069.innerHTML = "Hide Input";
#                     } else {
#                         input_1488052069.style.display = "none"; // hide
#                         link_1488052069.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1488052069 = $("a[id='1488052069']");
#                 var cell_1488052069 = link_1488052069.parents("div.cell:first");
#                 var input_1488052069 = cell_1488052069.children("div.input");
#                 input_1488052069.hide();
#
#                 toggle_input_1488052069 = function() {
#                     if (input_1488052069.is(':hidden')) {
#                         input_1488052069.slideDown();
#                         link_1488052069[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1488052069.slideUp();
#                         link_1488052069[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F (current-frequency) curve, if you're familiar with that).
#
# The tuning curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)

# %%
with nengo.Simulator(model) as sim:

    eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1256127607" href="javascript:toggle_input_1256127607()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1256127607;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1256127607 = document.getElementById("1256127607");
#                 var cell = link_1256127607;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1256127607;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1256127607 = cell.children[i];
#                 }
#                 input_1256127607.style.display = "none"; // hide
#
#                 toggle_input_1256127607 = function() {
#                     if (input_1256127607.style.display == "none") {
#                         input_1256127607.style.display = ""; // show
#                         link_1256127607.innerHTML = "Hide Input";
#                     } else {
#                         input_1256127607.style.display = "none"; // hide
#                         link_1256127607.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1256127607 = $("a[id='1256127607']");
#                 var cell_1256127607 = link_1256127607.parents("div.cell:first");
#                 var input_1256127607 = cell_1256127607.children("div.input");
#                 input_1256127607.hide();
#
#                 toggle_input_1256127607 = function() {
#                     if (input_1256127607.is(':hidden')) {
#                         input_1256127607.slideDown();
#                         link_1256127607[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1256127607.slideUp();
#                         link_1256127607[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="487316706" href="javascript:toggle_input_487316706()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_487316706;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_487316706 = document.getElementById("487316706");
#                 var cell = link_487316706;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_487316706;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_487316706 = cell.children[i];
#                 }
#                 input_487316706.style.display = "none"; // hide
#
#                 toggle_input_487316706 = function() {
#                     if (input_487316706.style.display == "none") {
#                         input_487316706.style.display = ""; // show
#                         link_487316706.innerHTML = "Hide Input";
#                     } else {
#                         input_487316706.style.display = "none"; // hide
#                         link_487316706.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_487316706 = $("a[id='487316706']");
#                 var cell_487316706 = link_487316706.parents("div.cell:first");
#                 var input_487316706 = cell_487316706.children("div.input");
#                 input_487316706.hide();
#
#                 toggle_input_487316706 = function() {
#                     if (input_487316706.is(':hidden')) {
#                         input_487316706.slideDown();
#                         link_487316706[0].innerHTML = "Hide Input";
#                     } else {
#                         input_487316706.slideUp();
#                         link_487316706[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded by decoding the pattern of spikes. To do this, we first filter the spike train with a temporal filter that accounts for postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 0.18
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:,i] - i*scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons+1), scale)
plt.ylabel("Neuron")
plt.yticks(np.arange(scale/1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons));
hide_input()
# Out:
#         <a id="740891559" href="javascript:toggle_input_740891559()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_740891559;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_740891559 = document.getElementById("740891559");
#                 var cell = link_740891559;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_740891559;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_740891559 = cell.children[i];
#                 }
#                 input_740891559.style.display = "none"; // hide
#
#                 toggle_input_740891559 = function() {
#                     if (input_740891559.style.display == "none") {
#                         input_740891559.style.display = ""; // show
#                         link_740891559.innerHTML = "Hide Input";
#                     } else {
#                         input_740891559.style.display = "none"; // hide
#                         link_740891559.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_740891559 = $("a[id='740891559']");
#                 var cell_740891559 = link_740891559.parents("div.cell:first");
#                 var input_740891559 = cell_740891559.children("div.input");
#                 input_740891559.hide();
#
#                 toggle_input_740891559 = function() {
#                     if (input_740891559.is(':hidden')) {
#                         input_740891559.slideDown();
#                         link_740891559[0].innerHTML = "Hide Input";
#                     } else {
#                         input_740891559.slideUp();
#                         link_740891559[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together to give an estimate of the input based on the spikes.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1348010184" href="javascript:toggle_input_1348010184()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1348010184;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1348010184 = document.getElementById("1348010184");
#                 var cell = link_1348010184;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1348010184;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1348010184 = cell.children[i];
#                 }
#                 input_1348010184.style.display = "none"; // hide
#
#                 toggle_input_1348010184 = function() {
#                     if (input_1348010184.style.display == "none") {
#                         input_1348010184.style.display = ""; // show
#                         link_1348010184.innerHTML = "Hide Input";
#                     } else {
#                         input_1348010184.style.display = "none"; // hide
#                         link_1348010184.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1348010184 = $("a[id='1348010184']");
#                 var cell_1348010184 = link_1348010184.parents("div.cell:first");
#                 var input_1348010184 = cell_1348010184.children("div.input");
#                 input_1348010184.hide();
#
#                 toggle_input_1348010184 = function() {
#                     if (input_1348010184.is(':hidden')) {
#                         input_1348010184.slideDown();
#                         link_1348010184[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1348010184.slideUp();
#                         link_1348010184[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1461047083" href="javascript:toggle_input_1461047083()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1461047083;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1461047083 = document.getElementById("1461047083");
#                 var cell = link_1461047083;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1461047083;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1461047083 = cell.children[i];
#                 }
#                 input_1461047083.style.display = "none"; // hide
#
#                 toggle_input_1461047083 = function() {
#                     if (input_1461047083.style.display == "none") {
#                         input_1461047083.style.display = ""; // show
#                         link_1461047083.innerHTML = "Hide Input";
#                     } else {
#                         input_1461047083.style.display = "none"; // hide
#                         link_1461047083.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1461047083 = $("a[id='1461047083']");
#                 var cell_1461047083 = link_1461047083.parents("div.cell:first");
#                 var input_1461047083 = cell_1461047083.children("div.input");
#                 input_1461047083.hide();
#
#                 toggle_input_1461047083 = function() {
#                     if (input_1461047083.is(':hidden')) {
#                         input_1461047083.slideDown();
#                         link_1461047083[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1461047083.slideUp();
#                         link_1461047083[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.processes import WhiteSignal

model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1919762439" href="javascript:toggle_input_1919762439()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1919762439;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1919762439 = document.getElementById("1919762439");
#                 var cell = link_1919762439;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1919762439;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1919762439 = cell.children[i];
#                 }
#                 input_1919762439.style.display = "none"; // hide
#
#                 toggle_input_1919762439 = function() {
#                     if (input_1919762439.style.display == "none") {
#                         input_1919762439.style.display = ""; // show
#                         link_1919762439.innerHTML = "Hide Input";
#                     } else {
#                         input_1919762439.style.display = "none"; // hide
#                         link_1919762439.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1919762439 = $("a[id='1919762439']");
#                 var cell_1919762439 = link_1919762439.parents("div.cell:first");
#                 var input_1919762439 = cell_1919762439.children("div.input");
#                 input_1919762439.hide();
#
#                 toggle_input_1919762439 = function() {
#                     if (input_1919762439.is(':hidden')) {
#                         input_1919762439.slideDown();
#                         link_1919762439[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1919762439.slideUp();
#                         link_1919762439[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input,)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="313333979" href="javascript:toggle_input_313333979()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_313333979;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_313333979 = document.getElementById("313333979");
#                 var cell = link_313333979;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_313333979;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_313333979 = cell.children[i];
#                 }
#                 input_313333979.style.display = "none"; // hide
#
#                 toggle_input_313333979 = function() {
#                     if (input_313333979.style.display == "none") {
#                         input_313333979.style.display = ""; // show
#                         link_313333979.innerHTML = "Hide Input";
#                     } else {
#                         input_313333979.style.display = "none"; // hide
#                         link_313333979.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_313333979 = $("a[id='313333979']");
#                 var cell_313333979 = link_313333979.parents("div.cell:first");
#                 var input_313333979 = cell_313333979.children("div.input");
#                 input_313333979.hide();
#
#                 toggle_input_313333979 = function() {
#                     if (input_313333979.is(':hidden')) {
#                         input_313333979.slideDown();
#                         link_313333979[0].innerHTML = "Hide Input";
#                     } else {
#                         input_313333979.slideUp();
#                         link_313333979[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes. We told Nengo to compute a new set of decoders that estimate the function $x^2$.
#
# In general, the transformation principle determines how we can decode spike trains to compute linear and nonlinear transformations of signals encoded in a population of neurons. We can then project those transformed signals into another population, and repeat the process.  Essentially, this provides a means of computing the neural connection weights to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="424863652" href="javascript:toggle_input_424863652()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_424863652;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_424863652 = document.getElementById("424863652");
#                 var cell = link_424863652;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_424863652;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_424863652 = cell.children[i];
#                 }
#                 input_424863652.style.display = "none"; // hide
#
#                 toggle_input_424863652 = function() {
#                     if (input_424863652.style.display == "none") {
#                         input_424863652.style.display = ""; // show
#                         link_424863652.innerHTML = "Hide Input";
#                     } else {
#                         input_424863652.style.display = "none"; // hide
#                         link_424863652.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_424863652 = $("a[id='424863652']");
#                 var cell_424863652 = link_424863652.parents("div.cell:first");
#                 var input_424863652 = cell_424863652.children("div.input");
#                 input_424863652.hide();
#
#                 toggle_input_424863652 = function() {
#                     if (input_424863652.is(':hidden')) {
#                         input_424863652.slideDown();
#                         link_424863652[0].innerHTML = "Hide Input";
#                     } else {
#                         input_424863652.slideUp();
#                         link_424863652[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights. Let us flip this sine wave upside down as it is transmitted between two populations (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2,2,3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2,2,2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2,2,4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="735122932" href="javascript:toggle_input_735122932()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_735122932;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_735122932 = document.getElementById("735122932");
#                 var cell = link_735122932;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_735122932;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_735122932 = cell.children[i];
#                 }
#                 input_735122932.style.display = "none"; // hide
#
#                 toggle_input_735122932 = function() {
#                     if (input_735122932.style.display == "none") {
#                         input_735122932.style.display = ""; // show
#                         link_735122932.innerHTML = "Hide Input";
#                     } else {
#                         input_735122932.style.display = "none"; // hide
#                         link_735122932.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_735122932 = $("a[id='735122932']");
#                 var cell_735122932 = link_735122932.parents("div.cell:first");
#                 var input_735122932 = cell_735122932.children("div.input");
#                 input_735122932.hide();
#
#                 toggle_input_735122932 = function() {
#                     if (input_735122932.is(':hidden')) {
#                         input_735122932.slideDown();
#                         link_735122932[0].innerHTML = "Hide Input";
#                     } else {
#                         input_735122932.slideUp();
#                         link_735122932[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights. Let us add a third population connected to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="128541699" href="javascript:toggle_input_128541699()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_128541699;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_128541699 = document.getElementById("128541699");
#                 var cell = link_128541699;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_128541699;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_128541699 = cell.children[i];
#                 }
#                 input_128541699.style.display = "none"; // hide
#
#                 toggle_input_128541699 = function() {
#                     if (input_128541699.style.display == "none") {
#                         input_128541699.style.display = ""; // show
#                         link_128541699.innerHTML = "Hide Input";
#                     } else {
#                         input_128541699.style.display = "none"; // hide
#                         link_128541699.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_128541699 = $("a[id='128541699']");
#                 var cell_128541699 = link_128541699.parents("div.cell:first");
#                 var input_128541699 = cell_128541699.children("div.input");
#                 input_128541699.hide();
#
#                 toggle_input_128541699 = function() {
#                     if (input_128541699.is(':hidden')) {
#                         input_128541699.slideDown();
#                         link_128541699[0].innerHTML = "Hide Input";
#                     } else {
#                         input_128541699.slideUp();
#                         link_128541699[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we have been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory or dynamic systems theory to brain models.  Nengo automatically translates from standard dynamical systems descriptions to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics, we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator implemented using this third principle. It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1,0] if t < 0.1 else [0,0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator,
                     transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1,2,2)
plt.plot(sim.data[oscillator_probe][:,0], sim.data[oscillator_probe][:,1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$');
hide_input()
# Out:
#         <a id="450220140" href="javascript:toggle_input_450220140()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_450220140;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_450220140 = document.getElementById("450220140");
#                 var cell = link_450220140;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_450220140;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_450220140 = cell.children[i];
#                 }
#                 input_450220140.style.display = "none"; // hide
#
#                 toggle_input_450220140 = function() {
#                     if (input_450220140.style.display == "none") {
#                         input_450220140.style.display = ""; // show
#                         link_450220140.innerHTML = "Hide Input";
#                     } else {
#                         input_450220140.style.display = "none"; // hide
#                         link_450220140.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_450220140 = $("a[id='450220140']");
#                 var cell_450220140 = link_450220140.parents("div.cell:first");
#                 var input_450220140 = cell_450220140.children("div.input");
#                 input_450220140.hide();
#
#                 toggle_input_450220140 = function() {
#                     if (input_450220140.is(':hidden')) {
#                         input_450220140.slideDown();
#                         link_450220140[0].innerHTML = "Hide Input";
#                     } else {
#                         input_450220140.slideUp();
#                         link_450220140[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
